# %% [markdown]
# <a href="https://colab.research.google.com/github/magitz/ai-thoughts/blob/main/AI_thoughts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My thoughts on A
#
# ## Things I want to do with AI
#
# * Have fun
# * Take over the world
